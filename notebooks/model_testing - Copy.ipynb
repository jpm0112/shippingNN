# %%
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit

# %%
df = pd.read_csv("../data/proc/test_final_kz.csv", parse_dates=["FECHA"])
df["FECHA"] = pd.to_datetime(df["FECHA"] + "-5", format="%Y-%W-%w")
df
# Out:
#          FECHA  RUTS_UNICOS_DIARIOS       CD      CFR        F    OTRO  \
# 0   2022-01-07                 2585  16372.0   9185.0  38606.0  5042.0
# 1   2022-01-14                 3162  19169.0  10410.0  47036.0  7045.0
# 2   2022-01-21                 2934  17280.0   8971.0  43070.0  7255.0
# 3   2022-01-28                 2870  14806.0   8851.0  44111.0  8654.0
# 4   2022-02-04                 3080  15746.0   8817.0  47491.0  4965.0
# ..         ...                  ...      ...      ...      ...     ...
# 152 2024-11-29                 2724  17933.0   5037.0  40728.0  8087.0
# 153 2024-12-06                 2824  18352.0   5512.0  41198.0  7556.0
# 154 2024-12-13                 3312  24176.0   7337.0  51330.0  7264.0
# 155 2024-12-20                 2735  15064.0   5698.0  39951.0  7023.0
# 156 2024-12-27                 1541   7761.0   3135.0  21263.0  2671.0
#
#      CMA CGM   COSCO  EVERGREEN  HAMBURG SUD / COLUMBUS LINE  ...  \
# 0     5346.0  2268.0     1700.0                       7248.0  ...
# 1     5402.0  2828.0     2514.0                       8371.0  ...
# 2     4887.0  4327.0     1847.0                       6337.0  ...
# 3     4345.0  4622.0     1334.0                       7098.0  ...
# 4     5950.0  2608.0     2844.0                       6333.0  ...
# ..       ...     ...        ...                          ...  ...
# 152   8816.0  5127.0     3330.0                         20.0  ...
# 153   9655.0  5144.0     4018.0                         32.0  ...
# 154  13621.0  5032.0     3408.0                         10.0  ...
# 155   7382.0  5800.0     4550.0                          2.0  ...
# 156   3346.0  2072.0     1769.0                          0.0  ...
#
#      BDIY Index  (R3)  Close_pct_change_XSICFEUW Index  (R4)  \
# 0              2289.0                              -0.057136
# 1              1764.0                               0.064214
# 2              1415.0                              -0.003163
# 3              1381.0                              -0.004937
# 4              1423.0                               0.030593
# ..                ...                                    ...
# 152            1167.0                              -0.111823
# 153            1051.0                              -0.006220
# 154             990.0                               0.141462
# 155             997.0                               0.007238
# 156             997.0                               0.000653
#
#      Close_pct_change_XSICFENE Index  (R1)  \
# 0                                 0.046369
# 1                                -0.009378
# 2                                -0.028867
# 3                                -0.003158
# 4                                -0.004476
# ..                                     ...
# 152                               0.250428
# 153                              -0.014683
# 154                               0.005365
# 155                              -0.006522
# 156                              -0.001392
#
#      Close_pct_change_XSICFESE Index  (L4)  \
# 0                                -0.011207
# 1                                -0.010926
# 2                                -0.025227
# 3                                -0.045924
# 4                                -0.044766
# ..                                     ...
# 152                               0.056053
# 153                               0.044779
# 154                              -0.019692
# 155                              -0.061276
# 156                              -0.005934
#
#      Close_pct_change_XSICNEFE Index  (R2)  \
# 0                                -0.034848
# 1                                 0.000785
# 2                                -0.023529
# 3                                -0.006426
# 4                                -0.076799
# ..                                     ...
# 152                              -0.017192
# 153                               0.002915
# 154                              -0.005814
# 155                               0.000000
# 156                               0.000000
#
#      Close_pct_change_XSICNESE Index  (L2)  \
# 0                                 0.030636
# 1                                 0.020560
# 2                                -0.067476
# 3                                -0.017699
# 4                                 0.073662
# ..                                     ...
# 152                               0.063291
# 153                              -0.025510
# 154                              -0.003490
# 155                               0.000000
# 156                              -0.003503
#
#      Close_pct_change_XSICUENE Index  (R1)  \
# 0                                 0.073733
# 1                                -0.021459
# 2                                 0.033626
# 3                                 0.022631
# 4                                 0.006916
# ..                                     ...
# 152                              -0.012195
# 153                               0.019400
# 154                               0.000000
# 155                               0.000000
# 156                              -0.005190
#
#      Close_pct_change_XSICUWFE Index  (L1)  \
# 0                                -0.098472
# 1                                 0.014124
# 2                                -0.016713
# 3                                 0.020774
# 4                                 0.008326
# ..                                     ...
# 152                              -0.020319
# 153                               0.016296
# 154                               0.008746
# 155                               0.000000
# 156                               0.000000
#
#      Close_pct_change_XSICNEUE Index  (L3)  Close_pct_change_BDIY Index  (R3)
# 0                                 0.031680                           0.032476
# 1                                -0.022104                          -0.229358
# 2                                -0.000455                          -0.197846
# 3                                 0.000455                          -0.024028
# 4                                 0.035801                           0.030413
# ..                                     ...                                ...
# 152                              -0.027490                          -0.138109
# 153                               0.035977                          -0.099400
# 154                               0.003189                          -0.058040
# 155                              -0.004239                           0.007071
# 156                               0.000000                           0.000000
#
# [157 rows x 121 columns]

# %%
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(df):
    train, test = df.iloc[train_index], df.iloc[test_index]
